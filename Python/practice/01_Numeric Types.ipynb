# %% [markdown]
# 02-1 숫자형

# %%
from tarfile import version

#정수형 변수
a = 123
a = -178
a = 0

# %%
#실수형 변수

a = 1.2
a = -3.5

#컴퓨터식 지수 표현방식
a = 4.24E10
a = 4.24e-10

print(a)
# Out:
# 4.24e-10

# %% [markdown]
# 8진수와 16진수

# %%
#8진수, 0o로 시작함
a = 0o177
print(a)
# Out:
# 127

# %%
#8진수와 10진수를 더하면?
b = 13
print(a+b)
# Out:
# 140

# %%
#16진수,0x로 시작
a = 0x8ff
b = 0xABC
print(a+b)
# Out:
# 5051

# %%
#10진수를 8, 16진수로 편하게 바꾸거나/출력하는 방법은?
#내장함수 oct()를 사용하면 됨
a = 50
#a를 8진수로 변환하기
def oct(a):
    return format(a, '08') #8자리 폭으로 0을 채워라
print(oct(a))
#10진수가 10진수로 출력됨, 왜?
# Out:
# 00000050

# %%
print(oct(a))

a = 50

print(oct(a))
print(format(a, 'o'))
# Out:
# 00000050
# 00000050
# 62

# %%
#10진수로 변환해주는 함수
#init()

#2진수로 변환해주는 함수
#bin()

#8진수로 변환해주는 함수
#oct()

#16진수로 변환해주는 함수
#hex()

# %%
bin(5)
print(bin(5))

oct(5)
print(oct(5))
# Out:
# 0b101
# 00000005

# %%
#진수 바꿔서 출력하기
a = 1534
print(format(a, 'o')) #o는 8진수(Octal)을 의미
print(format(a, 'b')) #b는 2진수를 의미
print(format(a, 'x')) #x는 16진수 의미
# Out:
# 2776
# 10111111110
# 5fe

# %% [markdown]
# 숫자형을 활용하기 위한 연산자

# %%
a = 3
b = 4

#더하기
a + b
# Out:
# 7

# %%
#빼기
a - b
# Out:
# -1

# %%
#곱하기
a * b
# Out:
# 12

# %%
#나누기
a / b
# Out:
# 0.75

# %%
#제곱

a = 3
b = 4
a ** b #3의 4승
# Out:
# 81

# %%
#나눗셈 후 나머지를 반환하는 연산자

a = 7
b = 3

a % b
# Out:
# 1

# %%
#나눗셈 후 몫을 반환하는 연산자

a // b
# Out:
# 2

# %%
(a % b) + (b * (a // b))
# Out:
# 7

# %% [markdown]
# 복합 연산자

# %%
a = 1

a = a + 1 #a+1로 계산된 값을 다시 a에 대입
print(a)
# Out:
# 2

# %%
a += 1 # <= a = a + 1
print(a)
# Out:
# 3

# %% [markdown]
# 02-2 문자열 자료형

# %%
#문자열 = 큰따옴표("")로 둘러싸여있는 것

# %%
#문자열을 만드는 방법 4가지

"Hello World" # 첫번째

'Python is fun' #두번째

"""Life is too short, You need Python""" #세번째

'''Life is too short, You need Python''' #네번째
# Out:
# 'Life is too short, You need Python'

# %%
food = "Python's favorite food is perl"
food
# Out:
# "Python's favorite food is perl"

# %%
say = '"Python is very easy." he says.'
print(say)
# Out:
# "Python is very easy." he says.

# %%
food = 'python\'s favorite food is perl'
say = "\"Python is very easy.\" he says."
print(say)
print(food)
# Out:
# "Python is very easy." he says.
# python's favorite food is perl

# %%
#줄 바꾸기

multiline = '''
Life is too short


you need Python'''


print(multiline)
# Out:
# Life is too short
#
#
# you need Python

# %% [markdown]
# 문자열 연산하기

# %%
#문자열 더해서 연결하기

head = "Python"
tail = " is fun!"
head + tail
# Out:
# 'Python is fun!'

# %%
body = """
REALLY
REALLY
REALLY
"""
SUB = head + body + tail

print(SUB)
# Out:
# Python
# REALLY
# REALLY
# REALLY
#  is fun!

# %%
print(SUB * 2)
# Out:
# Python
# REALLY
# REALLY
# REALLY
#  is fun!Python
# REALLY
# REALLY
# REALLY
#  is fun!

# %%
print("=" * 50)
print("First line")
print("=" * 50)
# Out:
# ...
# First line
# ...

# %%
#문자열 길이 구하기

a = "Life is too short"
print(len(a))
# Out:
# 17

# %%
#문자열 인덱싱

a = "Life is too short, you need Python"
print(a[3])
# Out:
# e

# %%
a[0]
# Out:
# 'L'

# %%
a[12]
# Out:
# 's'

# %%
a[-1]
# Out:
# 'n'

# %%
a[-2]
# Out:
# 'o'

# %%
#문자열 슬라이싱

a = "Life is too short, You need Python"
b = a[0] + a[1] + a[2] + a[3]
print(b)
# Out:
# Life

# %%
print(a[0:4])
# Out:
# Life

# %%
print(len(a))
for i in range(len(a)):
    print(a[i])
# Out:
# 34
# L
# i
# f
# e
#
# i
# s
#
# t
# o
# o
#
# s
# h
# o
# r
# t
# ,
#
# Y
# o
# u
#
# n
# e
# e
# d
#
# P
# y
# t
# h
# o
# n

# %%
a[17:]
# Out:
# ', You need Python'

# %%
a[:]
# Out:
# 'Life is too short, You need Python'

# %%
#슬라이싱으로 문자열 나누기

a = "20251126Rainy"
date = a[:8]
weather = a[8:]
print(date)
print(weather)
# Out:
# 20251126
# Rainy

# %%
year = a[:4]
day = a[4:8]
weather = a[8:]
print(year)
print(day)
print(weather)
# Out:
# 2025
# 1126
# Rainy

# %%
#문자열 포매팅

print("I eat %d apples" %3)

print("I eat %s apples" %"five")
# Out:
# I eat 3 apples
# I eat five apples

# %%
number = 3123
print("I eat %d apples" %number)
# Out:
# I eat 3123 apples

# %%
number = 10
day = "three"
print("I ate %d apples. so I was sick for %s days." %(number, day))
# Out:
# I ate 10 apples. so I was sick for three days.

# %%
#%s 포맷코드는 어떤 형태의 값이든 변환해 넣을 수 있다.

print("I have %s apples" %3)
print("rate is %s" %3.2345)
# Out:
# I have 3 apples
# rate is 3.2345

# %%
print("%10s" %"hi")

#%10s : 전체 길이가 10개인 문자열 공간에서 대입되는 값을 오른쪽으로 정렬하고, 그 앞의 나머지는 공백으로 남겨두라는 의미

print("%-10sjane." %"hi")
# Out:
#         hi
# hi        jane.

# %%
print("%0.4f"%3.42134234)

#%0.4f에서 '.'는 소수점 포인트, 그 뒤의 숫자 4 : 소수점 뒤에 나올 숫자의 개수 0 : 문자열의 길이에 상관하지 않겠다는 의미
# Out:
# 3.4213

# %%
print("%10.4f"  %3.421342314)
# Out:
#     3.4213

# %% [markdown]
# format 함수를 사용한 포매팅

# %%
print("I eat {0} apples".format(3))
print("I eat {0} apples" .format("five"))
# Out:
# I eat 3 apples
# I eat five apples

# %%
#숫자값을 가진 변수로 대입하기
number = 10
print("I eat {0} apples" .format(number))
# Out:
# I eat 10 apples

# %%
#2개 이상의 값 넣기

number = 123
day = "three"
print("I ate {0} apples. so I was sick for {1} days." .format(number, day))

#문자열의 {0}, {1}과 같은 인덱스 항목이 format 함수의 입력값으로 순서에 맞게 바뀐다.
# Out:
# I ate 123 apples. so I was sick for three days.

# %%
#이름으로 넣기

print("I ate {number} apples. so I was sick for {day} days." .format(number = 10, day = 123))

#{name} 형태를 사용할 경우 반드시 name=value와 같은 형태의 입력값이 있어야 한다.
# Out:
# I ate 10 apples. so I was sick for 123 days.

# %%
#인덱스와 이름을 혼용해서 넣기

print("I ate {0} apples. so I was sick for {day} days." .format(10, day = 3))
# Out:
# I ate 10 apples. so I was sick for 3 days.

# %%
#왼쪽 정렬
print("{0:<10}".format("hi"))

#오른쪽 정렬 : 화살표 방향을 생각하면 쉬움
print("{0:>10}" .format("hi"))

#가운데 정렬
print("{0:^10}".format("hi"))

#공백 채우기
print("{0:=^10}".format("hi"))
print("{0:~<10}".format("hi"))
# Out:
# hi
#         hi
#     hi
# ====hi====
# hi~~~~~~~~

# %%
#소수점 표현하기
y = 3.42134234
print("{0:0.4f}".format(y))

print("{0:10.4f}".format(y))
# Out:
# 3.4213
#     3.4213

# %%
#{또는} 문자 표현하기

print("{{ and }} ".format())
# Out:
# { and }

# %% [markdown]
# f 문자열 포매팅

# %%
name = '홍길동'
age = 29
f'나의 이름은 {name} 입니다. 나이는 {age}입니다.'

#f 문자열 포매팅은 변숫값을 생성한 후, 그 값을 참조할 수 있다.
# Out:
# '나의 이름은 홍길동 입니다. 나이는 29입니다.'

# %%
age = 30
f'나는 내년이면 {age+1}살이 된다.'

#f 문자열 포매팅은 표현식을 지원한다.
#표현식이란, 중괄호 안의 변수를 계산식과 함께 사용하는 것을 말한다.
# Out:
# '나는 내년이면 31살이 된다.'

# %%
#f 문자열에서 딕셔너리

d = {'name' : '홍길동', 'age' : 30}
f'나의 이름은 {d["name"]}입니다. 나이는 {d["age"]}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %%
#정렬

f'{"hi":<10}' #왼쪽 정렬

f'{"hi":>10}' #오른쪽 정렬

f'{"hi":^10}' #가운데 정렬
# Out:
# '    hi    '

# %%
#공백 채우기

f'{"hi":=^10}'
f'{"hi":=>10}'
f'{"hi":=<10}'
# Out:
# 'hi========'

# %%
#소수점 표현하기

y = 3.421342324
f'{y:0.4f}' #소수점 4자리까지만 표현
f'{y:10.4}' #소수점 4자리까지 표현하고 총 자리수를 10으로 맞춤
# Out:
# '     3.421'

# %%
f'{{  and  }}'
# Out:
# '{  and  }'

# %% [markdown]
# 문자열 관련 함수들

# %%
#문자 개수 세기 - count

a = "hobby"
a.count('b') #count 함수가 a 문자열 중 'b'의 개수를 반환했다.
# Out:
# 2

# %%
#위치 알려주기 - find

a = "Python is the best choice"
a.find('b') #문자열 중 b가 처음으로 나온 위치를 반환함
# Out:
# 14

# %%
a.find('k') #만약 찾는 문자나 문자열이 존재하지 않는다면 -1을 반환함
# Out:
# -1

# %%
#문자열 삽입 - join

",".join('abcd')
# Out:
# 'a,b,c,d'

# %%
#소문자를 대문자로 바꾸기

a = "hi"
a.upper()
# Out:
# 'HI'

# %%
#대문자를 소문자로 바꾸기

a = "HI"
a.lower()
# Out:
# 'hi'

# %%
#왼쪽 공백 지우기 -  rstrip

a = "   hi    "
a.rstrip()
# Out:
# '   hi'

# %%
#양쪽 공백 지우기 -  strip

a = "   hi   "
a.strip()
# Out:
# 'hi'

# %%
#문자열 바꾸기 - replace

a = "Life is too short"
a.replace("Life", "Your leg")

#replace함수는 replace(바뀔 문자열, 바꿀 문자열)처럼 사용해서 문자열 안의 특정한 값을 다른 값으로 치환해준다.
# Out:
# 'Your leg is too short'

# %%
#문자열 나누기 - split

a = "Life is too short"
print(a.split())

#split 함수는 ()안에 아무것도 넣어주지 않으면 공백을 기준으로 문자열을 나누어 준다.


b = "a:b:c:d"
print(b.split(':'))

#b.split(":")처럼 괄호 안에 특정 값이 있을 경우에는 괄호 안의 값을 구분자로 해서 문자열을 나누어준다.
# Out:
# ['Life', 'is', 'too', 'short']
# ['a', 'b', 'c', 'd']

# %%
#문자열이 알파벳으로만 구성되어 있는지 확인하기 - isalpha

s = "Python"
print(s.isalpha())

s = "Python3"
print(s.isalpha())

s = "Hello World"
print(s.isalpha())

# 공백이나 숫자, 특수문자가 포함되어 있으면 False를 반환함
# Out:
# True
# False
# False

# %%
#문자열이 숫자로만 구성되어 있는지 확인하기  - isdigit

s = "12345"
print(s.isdigit())

s = "123445a"
print(s.isdigit())

s = "123 123123 123"
print(s.isdigit())
# Out:
# True
# False
# False

# %%
#문자열이 특정 문자열로 시작하는지 확인하기 - startswith

s = "Life is too short"

print(s.startswith("Life"))

print(s.startswith("short"))

#startswith 함수는 문자열이 지정한 문자(열)로 시작하는지를 검사한다.
# Out:
# True
# False

# %%
#문자열이 특정 문자(열)로 끝나는지 확인하기 - endswith

s = "Life is too short"

print(s.endswith("short"))

print(s.endswith("Life"))
# Out:
# True
# False
